# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\ricar\Proyectos\Ruta Machine Learning\Fundamentos practicos Machine Learning\canciones-2018.csv")

# %%
data = pd.DataFrame(data)
data
# Out:
#                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %%
#Ordenamiento por canciones 
data.sort_values(by='name' , axis = 0 ,ascending = True )
# Out:
#                        id                                               name  \
# 77  4QtiVmuA88tPQiCOHZuQ5        1, 2, 3 (feat. Jason Derulo & De La Ghetto)
# 60  2BgEsaKNfHUdlh97KmvFy                                               2002
# 34  2hl6q70unbviGo3g1R7uF                                    ?chame La Culpa
# 15  3GCdLUSnKSMJhs4Tj6CV3                           All The Stars (with SZA)
# 47  4hQ6UGyWQIGJmHSo0J88J  Back To You - From 13 Reasons Why ? Season 2 S...
# ..                    ...                                                ...
# 23  2iUXsYOEPhVqEBwsqP70r                                         Youngblood
# 38  7AFASza1mXqntmGtbxXpr                                            changes
# 80  0u2P5u6lvoDfwTYjAADbn                               lovely (with Khalid)
# 16  2qT1uLXPVPzGgFOx4jtEu                               no tears left to cry
# 2   0e7ipj03S05BNilyu5bRz                         rockstar (feat. 21 Savage)
#
# ...

# %%
#Describiendo el tiempo de una cancion en milisengundos
data.duration_ms.describe()
# Out:
# count       100.000000
# mean     205206.780000
# std       40007.893404
# min       95467.000000
# 25%      184680.000000
# 50%      205047.500000
# 75%      221493.250000
# max      417920.000000
# Name: duration_ms, dtype: float64

# %%
#Artita y nombre de la cancion con la duracion mas larga:
artista_long = data.sort_values(by='duration_ms' , axis = 0 ,ascending = False )
artista_long = artista_long.head(1)
artista_long
# Out:
#                        id             name     artists  danceability  energy  \
# 21  3V8UKqhEK5zBkBb6d6ub8  Te Bot? - Remix  Nio Garcia         0.903   0.675
#
#      key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 21  11.0    -3.445   0.0        0.214         0.542          0.000013
#
#     liveness  valence   tempo  duration_ms  time_signature
# 21    0.0595    0.442  96.507     417920.0             4.0

# %%
artista_long.iloc[:,[1,2,14]]
# Out:
#                name     artists  duration_ms
# 21  Te Bot? - Remix  Nio Garcia     417920.0
